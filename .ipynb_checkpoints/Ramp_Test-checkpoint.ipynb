# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\fisuk\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: C:\Users\fisuk\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import requests
from pprint import pprint
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
CLIENT_ID = os.getenv("RAMP_CLIENT_ID")
CLIENT_SECRET = os.getenv("RAMP_CLIENT_SECRET")

# %%
if not CLIENT_ID or not CLIENT_SECRET:
    raise RuntimeError("Set RAMP_CLIENT_ID and RAMP_CLIENT_SECRET")

BASE_URL = "https://api.ramp.com/developer/v1"
TOKEN_URL = "https://api.ramp.com/developer/v1/token"

# %%
_access_token = None
_expires_at = 0

def get_access_token():
    global _access_token, _expires_at

    if _access_token and time.time() < _expires_at:
        return _access_token

    resp = requests.post(
        TOKEN_URL,
        data={
            "grant_type": "client_credentials",
            "client_id": CLIENT_ID,
            "client_secret": CLIENT_SECRET,
            # "scope": "transactions vendors users"  # if required
        },
        headers={"Accept": "application/json"},
    )
    resp.raise_for_status()

    token = resp.json()
    _access_token = token["access_token"]
    _expires_at = time.time() + token.get("expires_in", 3600) - 30

    return _access_token

# %%
def ramp_headers():
    return {
        "Authorization": f"Bearer {get_access_token()}",
        "Content-Type": "application/json",
        "Accept": "application/json",
    }

def ramp_get(endpoint, params=None):
    url = f"{BASE_URL}{endpoint}"
    resp = requests.get(url, headers=ramp_headers(), params=params)
    resp.raise_for_status()
    return resp.json()

def ramp_post(endpoint, payload=None):
    url = f"{BASE_URL}{endpoint}"
    resp = requests.post(url, headers=ramp_headers(), json=payload)
    resp.raise_for_status()
    return resp.json()

# %%
# Transactions
acct_fields = ramp_get("/accounting/fields")
pprint(acct_fields)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Transactions
# ----> 2 acct_fields = ramp_get("/accounting/fields")
#       3 pprint(acct_fields)
#
# Cell In[20], line 10, in ramp_get(endpoint, params)
#       8 def ramp_get(endpoint, params=None):
#       9     url = f"{BASE_URL}{endpoint}"
# ---> 10     resp = requests.get(url, headers=ramp_headers(), params=params)
#      11     resp.raise_for_status()
#      12     return resp.json()
#
# Cell In[20], line 3, in ramp_headers()
#       1 def ramp_headers():
#       2     return {
# ----> 3         "Authorization": f"Bearer {get_access_token()}",
#       4         "Content-Type": "application/json",
#       5         "Accept": "application/json",
#       6     }
#
# Cell In[19], line 20, in get_access_token()
#       8     return _access_token
#      10 resp = requests.post(
#      11     TOKEN_URL,
#      12     data={
#    (...)     18     headers={"Accept": "application/json"},
#      19 )
# ---> 20 resp.raise_for_status()
#      22 token = resp.json()
#      23 _access_token = token["access_token"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.ramp.com/developer/v1/token
